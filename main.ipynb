# %%
# Importacoes e Configuracao do Pandas 
import pandas as pd


pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)

# %%
# Variaveis 

PATH_INPUT_SHEET_ORDERS_RELEASED = "./data_input/Planilha_Azul.xlsx"
PATH_INPUT_SHEET_ORDERS_BLOCKED = "./data_input/Planilha_Amarela.xlsx"

COLUMN_NAME_SHEET_ORDERS_RELEASED = ["Confirmed_receipt_date","Review_date","Mark","Release_reason","Sales_order","Name","Sales_total","Customer_account","Warehouse","Customer_group","Released","Sales_responsible","Credit_control_group","Modified_by","Active","Released_by","Sales_taker","Credit_control_number","Masterpack_reference","Ship_date","Credit_control_reason","Document_status","Load_ID","Terms_of_payment","Forced_hold_reason","Company"
]
COLUMN_NAME_SHEET_ORDERS_BLOCKED = ["On_First_Failed_Queue","KPI","Before_9am","Advanced","Morning_Queue","Error_Type","Replen_Line","Cost_Centre","Warehouse","Confirmed_pick_date","Ship_complete2","Do_not_consolidate","In_credit_control","Expedite","Delivery_zone","Sales_order","Sales_origin","Customer","Name","Item_number","Customer_reference","Quantity_available_to_release","Quantity","Product_name","Inventory_unit","Site","Batch_Number","Location","Inventory_status","Licence_plate","Delivery_name","Customer_reference2","City","State","Postcode","Confirmed_receipt_date","Modified_by","Mode_of_delivery","Modified_date_and_time","Created_date_and_time","Address","Do_not_process","Sales_Group","Customer_group","Product_posting_group","COGs_Estimate"]

COLUMN_NAME_OUTPUT_FILE = []
OUTPUT_FILE = "./data_output/ORDERS_BLOCKED.xlsx"

# %%
# Leitura das Planilhas 

df_orders_released = pd.read_excel(PATH_INPUT_SHEET_ORDERS_RELEASED, skiprows=1, names=COLUMN_NAME_SHEET_ORDERS_RELEASED)
df_orders_blocked  = pd.read_excel(PATH_INPUT_SHEET_ORDERS_BLOCKED,  skiprows=2, names=COLUMN_NAME_SHEET_ORDERS_BLOCKED)

# %%
## Remoção de Duplicados - Regra 1 
df_orders_blocked = df_orders_blocked.drop_duplicates(subset=["Sales_order"]) # Remover duplicados apenas dos pedidos bloqueados

## Filtrar a coluna Credit Control - Regra 2
df_orders_blocked = df_orders_blocked[df_orders_blocked["In_credit_control"] == "Yes"]

## Filtrar a coluna Cost Center por Residencial - Regra 3 
df_orders_blocked = df_orders_blocked[df_orders_blocked["Cost_Centre"].str.contains("Residential")]

print(df_orders_blocked.head())
# Out:
#                                 On_First_Failed_Queue                                                KPI                                         Before_9am Advanced            Morning_Queue                                         Error_Type Replen_Line                    Cost_Centre Warehouse  Confirmed_pick_date Ship_complete2 Do_not_consolidate In_credit_control Expedite Delivery_zone Sales_order Sales_origin   Customer                                               Name Item_number Customer_reference Quantity_available_to_release Quantity                Product_name Inventory_unit Site Batch_Number Location Inventory_status Licence_plate                                      Delivery_name Customer_reference2             City State Postcode Confirmed_receipt_date Modified_by Mode_of_delivery Modified_date_and_time Created_date_and_time                                        Address Do_not_process Sales_Group Customer_group Product_posting_group COGs_Estimate
# 19  Sales / WH - Ship Complete Issue - Single Line...  Sales / WH - Ship Complete Issue - Single Line...  Sales / WH - Ship Complete Issue - Single Line...      YES  VICA015915251001983-136  Sales / WH - Ship Complete Issue - Single Line...         NaN  31010 - VIC Residential Trade       VIC  2024-08-07 00:00:00             No                 No               Yes      NaN           301   A01591525      TRD-ORD  C00080684  SHALUX PTY LTD T/AS SHALUX TILING & STONE SERV...     1001983                NaN                     13,440.00  -136.00  United White Satin 100x300             Ea  VIC          NaN      NaN          INV-AVL           NaN  SHALUX PTY LTD T/AS SHALUX TILING & STONE SERV...                 NaN  NORTH MELBOURNE   VIC     3051    2024-08-08 00:00:00    chris.ro          CUS-DEL    2024-08-06 10:15:00   2023-12-07 18:40:00  11 Molesworth St \n NORTH MELBOURNE, VIC 3051             No     CUS-TRK          TRADE                   NaN           NaN

# %%
# Merge entre as duas planilhas utilizando o Sales_Order como chave. 

df_merge_orders = pd.merge(df_orders_released, df_orders_blocked, on="Sales_order", how="inner")

df_merge_orders.head()
# Out:
#   Confirmed_receipt_date_x Review_date Mark Release_reason Sales_order              Name_x Sales_total Customer_account Warehouse_x Customer_group_x            Released              Sales_responsible Credit_control_group Modified_by_x Active Released_by  Sales_taker Credit_control_number  Masterpack_reference  Ship_date Credit_control_reason       Document_status  Load_ID  Terms_of_payment  Forced_hold_reason Company                              On_First_Failed_Queue                                                KPI                                         Before_9am Advanced            Morning_Queue                                         Error_Type Replen_Line                    Cost_Centre Warehouse_y  Confirmed_pick_date Ship_complete2 Do_not_consolidate In_credit_control Expedite Delivery_zone Sales_origin   Customer                                             Name_y Item_number Customer_reference Quantity_available_to_release Quantity                Product_name Inventory_unit  \
# 0               2025-02-28         NaT   No             AR   A01591525  ULTRA LIVING HOMES    9,833.36        C00030748         QLD            TRADE 2025-02-27 06:08:00  National Customer Service QLD              15D-GCE      tiffany.     No    tiffany.          NaN            CC00089300                   NaN 2025-02-27       Invoice overdue  Release to warehouse      NaN               NaN                 NaN    btau  Sales / WH - Ship Complete Issue - Single Line...  Sales / WH - Ship Complete Issue - Single Line...  Sales / WH - Ship Complete Issue - Single Line...      YES  VICA015915251001983-136  Sales / WH - Ship Complete Issue - Single Line...         NaN  31010 - VIC Residential Trade         VIC  2024-08-07 00:00:00             No                 No               Yes      NaN           301      TRD-ORD  C00080684  SHALUX PTY LTD T/AS SHALUX TILING & STONE SERV...     1001983                NaN                     13,440.00  -136.00  United White Satin 100x300             Ea
#
#   Site Batch_Number Location Inventory_status Licence_plate                                      Delivery_name Customer_reference2             City State Postcode Confirmed_receipt_date_y Modified_by_y Mode_of_delivery Modified_date_and_time Created_date_and_time                                        Address Do_not_process Sales_Group Customer_group_y Product_posting_group COGs_Estimate
# 0  VIC          NaN      NaN          INV-AVL           NaN  SHALUX PTY LTD T/AS SHALUX TILING & STONE SERV...                 NaN  NORTH MELBOURNE   VIC     3051      2024-08-08 00:00:00      chris.ro          CUS-DEL    2024-08-06 10:15:00   2023-12-07 18:40:00  11 Molesworth St \n NORTH MELBOURNE, VIC 3051             No     CUS-TRK            TRADE                   NaN           NaN

# %%
quantidade_linhas = df_merge_orders.shape[0]

if quantidade_linhas == 0:
    print("Não há pedidos bloqueados para hoje")
else: 
    #df_merge_orders = df_merge_orders[COLUMN_NAME_OUTPUT_FILE]  # Caso necessario colunas especificas.
    df_merge_orders.to_excel(OUTPUT_FILE, index=False)
